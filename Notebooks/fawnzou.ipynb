# %%
# SQLAlchemy
from sqlalchemy import create_engine, inspect
import pandas as pd
# Path to sqlite

# Path to sqlite
database_path = "../Data/wdi_kaggle.sqlite"

# Create an engine that can talk to the database
engine = create_engine(f"sqlite:///{database_path}")
#from sqlalchemy import inspect
for table_name in inspect(engine).get_table_names():
   print(table_name)
# Out:
# Country
# CountryNotes
# Footnotes
# Indicators
# Series
# SeriesNotes

# %%
conn= engine.connect()
Country_df= pd.read_sql("select * from Country",conn)
CountryNotes_df= pd.read_sql("select * from Country",conn)
Footnotes_df= pd.read_sql("select * from Country",conn)
Indicators_df= pd.read_sql("select * from Country",conn)
Series_df= pd.read_sql("select * from Country",conn)
SeriesNotes_df= pd.read_sql("select * from Country",conn)

# %%
# Save all dataframes as csv files
Country_df.to_csv("out_put\Country.csv",index=False)
CountryNotes_df.to_csv("out_put\CountryNotes.csv",index=False)
Footnotes_df.to_csv("out_put\Footnotes.csv",index=False)
Indicators_df.to_csv("out_put\Indicators.csv",index=False)
Series_df.to_csv("out_put\Series.csv",index=False)
SeriesNotes_df.to_csv("out_put\SeriesNotes.csv",index=False)

# %%
Country_df.head()
# Out:
#   CountryCode       ShortName       TableName  \
# 0         AFG     Afghanistan     Afghanistan
# 1         ALB         Albania         Albania
# 2         DZA         Algeria         Algeria
# 3         ASM  American Samoa  American Samoa
# 4         ADO         Andorra         Andorra
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
# 3                           American Samoa         AS     U.S. dollar
# 4                  Principality of Andorra         AD            Euro
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1
# 2
# 3
# 4
#
#                        Region           IncomeGroup Wb2Code  ...  \
# 0                  South Asia            Low income      AF  ...
# ...

# %%
len(Country_df)
# Out:
# 247

# %%
CountryNotes_df.head()
# Out:
#   CountryCode       ShortName       TableName  \
# 0         AFG     Afghanistan     Afghanistan
# 1         ALB         Albania         Albania
# 2         DZA         Algeria         Algeria
# 3         ASM  American Samoa  American Samoa
# 4         ADO         Andorra         Andorra
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
# 3                           American Samoa         AS     U.S. dollar
# 4                  Principality of Andorra         AD            Euro
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1
# 2
# 3
# 4
#
#                        Region           IncomeGroup Wb2Code  ...  \
# 0                  South Asia            Low income      AF  ...
# ...

# %%
Footnotes_df.head()
# Out:
#   CountryCode       ShortName       TableName  \
# 0         AFG     Afghanistan     Afghanistan
# 1         ALB         Albania         Albania
# 2         DZA         Algeria         Algeria
# 3         ASM  American Samoa  American Samoa
# 4         ADO         Andorra         Andorra
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
# 3                           American Samoa         AS     U.S. dollar
# 4                  Principality of Andorra         AD            Euro
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1
# 2
# 3
# 4
#
#                        Region           IncomeGroup Wb2Code  ...  \
# 0                  South Asia            Low income      AF  ...
# ...

# %%
Series_df.head()
# Out:
#   CountryCode       ShortName       TableName  \
# 0         AFG     Afghanistan     Afghanistan
# 1         ALB         Albania         Albania
# 2         DZA         Algeria         Algeria
# 3         ASM  American Samoa  American Samoa
# 4         ADO         Andorra         Andorra
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
# 3                           American Samoa         AS     U.S. dollar
# 4                  Principality of Andorra         AD            Euro
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1
# 2
# 3
# 4
#
#                        Region           IncomeGroup Wb2Code  ...  \
# 0                  South Asia            Low income      AF  ...
# ...

# %%
SeriesNotes_df.head()
# Out:
#   CountryCode       ShortName       TableName  \
# 0         AFG     Afghanistan     Afghanistan
# 1         ALB         Albania         Albania
# 2         DZA         Algeria         Algeria
# 3         ASM  American Samoa  American Samoa
# 4         ADO         Andorra         Andorra
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
# 3                           American Samoa         AS     U.S. dollar
# 4                  Principality of Andorra         AD            Euro
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1
# 2
# 3
# 4
#
#                        Region           IncomeGroup Wb2Code  ...  \
# 0                  South Asia            Low income      AF  ...
# ...

# %%
list(Country_df)
# Out:
# ['CountryCode',
#  'ShortName',
#  'TableName',
#  'LongName',
#  'Alpha2Code',
#  'CurrencyUnit',
#  'SpecialNotes',
#  'Region',
#  'IncomeGroup',
#  'Wb2Code',
#  'NationalAccountsBaseYear',
#  'NationalAccountsReferenceYear',
#  'SnaPriceValuation',
#  'LendingCategory',
#  'OtherGroups',
#  'SystemOfNationalAccounts',
#  'AlternativeConversionFactor',
#  'PppSurveyYear',
#  'BalanceOfPaymentsManualInUse',
#  'ExternalDebtReportingStatus',
#  'SystemOfTrade',
#  'GovernmentAccountingConcept',
#  'ImfDataDisseminationStandard',
#  'LatestPopulationCensus',
#  'LatestHouseholdSurvey',
#  'SourceOfMostRecentIncomeAndExpenditureData',
#  'VitalRegistrationComplete',
#  'LatestAgriculturalCensus',
#  'LatestIndustrialData',
#  'LatestTradeData',
#  'LatestWaterWithdrawalData']

# %%
list(CountryNotes_df)
# Out:
# ['CountryCode',
#  'ShortName',
#  'TableName',
#  'LongName',
#  'Alpha2Code',
#  'CurrencyUnit',
#  'SpecialNotes',
#  'Region',
#  'IncomeGroup',
#  'Wb2Code',
#  'NationalAccountsBaseYear',
#  'NationalAccountsReferenceYear',
#  'SnaPriceValuation',
#  'LendingCategory',
#  'OtherGroups',
#  'SystemOfNationalAccounts',
#  'AlternativeConversionFactor',
#  'PppSurveyYear',
#  'BalanceOfPaymentsManualInUse',
#  'ExternalDebtReportingStatus',
#  'SystemOfTrade',
#  'GovernmentAccountingConcept',
#  'ImfDataDisseminationStandard',
#  'LatestPopulationCensus',
#  'LatestHouseholdSurvey',
#  'SourceOfMostRecentIncomeAndExpenditureData',
#  'VitalRegistrationComplete',
#  'LatestAgriculturalCensus',
#  'LatestIndustrialData',
#  'LatestTradeData',
#  'LatestWaterWithdrawalData']

# %%
list(Footnotes_df)
# Out:
# ['CountryCode',
#  'ShortName',
#  'TableName',
#  'LongName',
#  'Alpha2Code',
#  'CurrencyUnit',
#  'SpecialNotes',
#  'Region',
#  'IncomeGroup',
#  'Wb2Code',
#  'NationalAccountsBaseYear',
#  'NationalAccountsReferenceYear',
#  'SnaPriceValuation',
#  'LendingCategory',
#  'OtherGroups',
#  'SystemOfNationalAccounts',
#  'AlternativeConversionFactor',
#  'PppSurveyYear',
#  'BalanceOfPaymentsManualInUse',
#  'ExternalDebtReportingStatus',
#  'SystemOfTrade',
#  'GovernmentAccountingConcept',
#  'ImfDataDisseminationStandard',
#  'LatestPopulationCensus',
#  'LatestHouseholdSurvey',
#  'SourceOfMostRecentIncomeAndExpenditureData',
#  'VitalRegistrationComplete',
#  'LatestAgriculturalCensus',
#  'LatestIndustrialData',
#  'LatestTradeData',
#  'LatestWaterWithdrawalData']

# %%
# list
# Out:
# ['CountryCode',
#  'ShortName',
#  'TableName',
#  'LongName',
#  'Alpha2Code',
#  'CurrencyUnit',
#  'SpecialNotes',
#  'Region',
#  'IncomeGroup',
#  'Wb2Code',
#  'NationalAccountsBaseYear',
#  'NationalAccountsReferenceYear',
#  'SnaPriceValuation',
#  'LendingCategory',
#  'OtherGroups',
#  'SystemOfNationalAccounts',
#  'AlternativeConversionFactor',
#  'PppSurveyYear',
#  'BalanceOfPaymentsManualInUse',
#  'ExternalDebtReportingStatus',
#  'SystemOfTrade',
#  'GovernmentAccountingConcept',
#  'ImfDataDisseminationStandard',
#  'LatestPopulationCensus',
#  'LatestHouseholdSurvey',
#  'SourceOfMostRecentIncomeAndExpenditureData',
#  'VitalRegistrationComplete',
#  'LatestAgriculturalCensus',
#  'LatestIndustrialData',
#  'LatestTradeData',
#  'LatestWaterWithdrawalData']

# %%
list(Series_df)
# Out:
# ['CountryCode',
#  'ShortName',
#  'TableName',
#  'LongName',
#  'Alpha2Code',
#  'CurrencyUnit',
#  'SpecialNotes',
#  'Region',
#  'IncomeGroup',
#  'Wb2Code',
#  'NationalAccountsBaseYear',
#  'NationalAccountsReferenceYear',
#  'SnaPriceValuation',
#  'LendingCategory',
#  'OtherGroups',
#  'SystemOfNationalAccounts',
#  'AlternativeConversionFactor',
#  'PppSurveyYear',
#  'BalanceOfPaymentsManualInUse',
#  'ExternalDebtReportingStatus',
#  'SystemOfTrade',
#  'GovernmentAccountingConcept',
#  'ImfDataDisseminationStandard',
#  'LatestPopulationCensus',
#  'LatestHouseholdSurvey',
#  'SourceOfMostRecentIncomeAndExpenditureData',
#  'VitalRegistrationComplete',
#  'LatestAgriculturalCensus',
#  'LatestIndustrialData',
#  'LatestTradeData',
#  'LatestWaterWithdrawalData']

# %%
list(SeriesNotes_df)
# Out:
# ['CountryCode',
#  'ShortName',
#  'TableName',
#  'LongName',
#  'Alpha2Code',
#  'CurrencyUnit',
#  'SpecialNotes',
#  'Region',
#  'IncomeGroup',
#  'Wb2Code',
#  'NationalAccountsBaseYear',
#  'NationalAccountsReferenceYear',
#  'SnaPriceValuation',
#  'LendingCategory',
#  'OtherGroups',
#  'SystemOfNationalAccounts',
#  'AlternativeConversionFactor',
#  'PppSurveyYear',
#  'BalanceOfPaymentsManualInUse',
#  'ExternalDebtReportingStatus',
#  'SystemOfTrade',
#  'GovernmentAccountingConcept',
#  'ImfDataDisseminationStandard',
#  'LatestPopulationCensus',
#  'LatestHouseholdSurvey',
#  'SourceOfMostRecentIncomeAndExpenditureData',
#  'VitalRegistrationComplete',
#  'LatestAgriculturalCensus',
#  'LatestIndustrialData',
#  'LatestTradeData',
#  'LatestWaterWithdrawalData']

# %%
# Scrape table(Unemployment) from WDI website

url="http://wdi.worldbank.org/table/2.5#"
tables = pd.read_html(url)

# %%
tables = pd.read_html(url)

# %%
tables[1]
# Out:
# Empty DataFrame
# ...

# %%
df1=tables[1]
columns = list(df1)
columns = [list(i) for i in columns]
columns
# Out:
# [['Unnamed: 0_level_0', 'Unnamed: 0_level_1'],
#  ['Unemployment, male (% of male labor force) (modeled ILO estimate)', '2000'],
#  ['Unemployment, male (% of male labor force) (modeled ILO estimate)', '2017'],
#  ['Unemployment, female (% of female labor force) (modeled ILO estimate)',
#   '2000'],
#  ['Unemployment, female (% of female labor force) (modeled ILO estimate)',
#   '2017'],
#  ['Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
#   '2000'],
#  ['Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
#   '2017'],
#  ['Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
#   '2000'],
#  ['Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
#   '2017'],
#  ['Unemployment with basic education (% of total labor force with basic education)',
#   '2014-17'],
# ...

# %%
# Moderate the columns
columns[0] ="ShortName"
for i in range(1,len(columns)):
    if i<8:
        columns[i] = columns[i][0].lstrip("Unemployment,").lstrip()+" " + columns[i][1]
    else:
        columns[i] = columns[i][0].lstrip("Unemployment with ")+" "+ "2014-2017"

# %%
columns
# Out:
# ['ShortName',
#  'male (% of male labor force) (modeled ILO estimate) 2000',
#  'male (% of male labor force) (modeled ILO estimate) 2017',
#  'female (% of female labor force) (modeled ILO estimate) 2000',
#  'female (% of female labor force) (modeled ILO estimate) 2017',
#  'youth male (% of male labor force ages 15-24) (modeled ILO estimate) 2000',
#  'youth male (% of male labor force ages 15-24) (modeled ILO estimate) 2017',
#  'youth female (% of female labor force ages 15-24) (modeled ILO estimate) 2000',
#  ', youth female (% of female labor force ages 15-24) (modeled ILO estimate) 2014-2017',
#  'basic education (% of total labor force with basic education) 2014-2017',
#  'rmediate education (% of total labor force with intermediate education) 2014-2017',
#  'advanced education (% of total labor force with advanced education) 2014-2017']

# %%
tables[2]
# Out:
#                                                     0     1     2     3   \
# 0                                          Afghanistan   3.8   1.1   3.0
# 1                                              Albania  17.4  14.6  18.2
# 2                                              Algeria  29.8  10.0  29.7
# 3                                       American Samoa    ..    ..    ..
# 4                                              Andorra    ..    ..    ..
# 5                                               Angola  20.7   6.8  25.0
# 6                                  Antigua and Barbuda    ..    ..    ..
# 7                                            Argentina  14.0   7.5  16.4
# 8                                              Armenia   8.2  18.1  14.7
# 9                                                Aruba    ..    ..    ..
# 10                                           Australia   6.5   5.5   6.1
# 11                                             Austria   4.8   5.9   4.6
# ...

# %%
tables[2]
unemplyment_df= tables[2]
unemplyment_df.columns=columns

# %%
unemplyment_df.head(30)
# Out:
#                  ShortName  \
# 0              Afghanistan
# 1                  Albania
# 2                  Algeria
# 3           American Samoa
# 4                  Andorra
# 5                   Angola
# 6      Antigua and Barbuda
# 7                Argentina
# 8                  Armenia
# 9                    Aruba
# 10               Australia
# 11                 Austria
# 12              Azerbaijan
# 13            Bahamas, The
# 14                 Bahrain
# 15              Bangladesh
# 16                Barbados
# 17                 Belarus
# 18                 Belgium
# 19                  Belize
# 20                   Benin
# 21                 Bermuda
# 22                  Bhutan
# 23                 Bolivia
# 24  Bosnia and Herzegovina
# 25                Botswana
# 26                  Brazil
# 27  British Virgin Islands
# 28       Brunei Darussalam
# 29                Bulgaria
#
#    male (% of male labor force) (modeled ILO estimate) 2000  \
# ...
